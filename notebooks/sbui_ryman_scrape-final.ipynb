# %%
import pandas as pd
import requests
from bs4 import BeautifulSoup as BS
import re

# %%
# im dead

# %%
# Scrape Ryman events from URL and iterate through 5 following events pages.

# create empty tables to dump times and performer results into
all_days = []
all_times = []
all_perf = [] 
all_open = []

for u in range(1,6):
# convert range values to string to concat with url string
    page = str(u)
    
# apply string to end of url
    url = 'https://ryman.com/events/list/?tribe_event_display=list&tribe_paged=' + page
    
# print url while running loop to check page number iteration
    print(url)
    
# request html from url source
    r = requests.get(url)
    print(r.status_code)

# soup html from request as text
    soup = BS(r.text)
    
# find time tags
    showtimes = soup.findAll('time')
    
# select text from html time table 'showtimes'
    times_list = [x.text for x in showtimes]
    
# find event performer names from 'h2' using class identifier, to table 'performances'
    performances = soup.findAll('h2', attrs={'class':'tribe-events-list-event-title'})
    
# select text from html results table 'performances'
    perf_list = [x.find('a').get('title') for x in performances]
    
# extract date
    days = [i.split('day, ')[1].split('at ')[0] for i in times_list]

# extract times
    time = [i.split('t ')[1] for i in times_list]

# dump results into above created tables and add newly iterated results to the tables
    all_days += days
    all_times += time
    all_perf += perf_list
    
# find openers
    opener_data = soup.find_all('div', attrs = {'class':'tribe-beside-image'})
# if no openers exist in div/class, display message
    for x in opener_data:
        openers = x.find('span', class_='opener').text if x.find('span', class_='opener') else '<No Opening Act>'
# if opener text is less than 3 characters, display message        
        if len(openers) < 3:
            all_open.append('<No Opening Act')
        else:
            all_open.append(openers)
            
# create empty DF for times and performer results
everything = pd.DataFrame()

# create df column for artists and showtimes, populate from previous dump tables
everything['artist'] = all_perf
everything['day'] = all_days
everything['time'] = all_times
everything['opening_acts'] = all_open

# check final df results
everything.head(15)
# Out:
# https://ryman.com/events/list/?tribe_event_display=list&tribe_paged=1
# 200
# https://ryman.com/events/list/?tribe_event_display=list&tribe_paged=2
# 200
# https://ryman.com/events/list/?tribe_event_display=list&tribe_paged=3
# 200
# https://ryman.com/events/list/?tribe_event_display=list&tribe_paged=4
# 200
# https://ryman.com/events/list/?tribe_event_display=list&tribe_paged=5
# 200
#                                           artist                 day  \
# 0                                   Tauren Wells  November 15, 2022
# 1                                    Sometimes Y  November 17, 2022
# 2               Trombone Shorty & Orleans Avenue  November 18, 2022
# 3                               Dropkick Murphys  November 19, 2022
# 4   JOHNNYSWIM, Bryan Sutton & Dr. Curt Thompson  November 20, 2022
# 5                 Opry NextStage Live In Concert  November 20, 2022
# 6                               Christmas 4 Kids  November 21, 2022
# 7                                    Omar Apollo  November 22, 2022
# 8                                       W.A.S.P.  November 23, 2022
# 9                                 Brett Eldredge  November 25, 2022
# 10                                Brett Eldredge  November 26, 2022
# 11                                Brett Eldredge  November 27, 2022
# 12                   Natalie Grant & Danny Gokey  November 28, 2022
# 13                             A Day To Remember  November 29, 2022
# 14                                The Piano Guys  November 30, 2022
#
#            time                                       opening_acts
# 0   7:30 PM CST  with special guests Aaron Cole and Lakewood Music
# 1   7:30 PM CST              Yelawolf & Shooter Jennings introduce
# 2   8:00 PM CST                              with Devon Gilfillian
# 3   7:30 PM CST                      This Machine ... Theater Tour
# 4   7:30 PM CST   Tokens Show presents No Small Endeavor featuring
# 5   7:30 PM CST                                    <No Opening Act
# 6   7:00 PM CST  with special guests Chris Young, Phil Vassar, ...
# 7   7:30 PM CST                                 The Prototype Tour
# 8   7:30 PM CST                           40 Years Live World Tour
# 9   8:00 PM CST                                     Glow Live Tour
# 10  8:00 PM CST                                     Glow Live Tour
# 11  8:00 PM CST                                     Glow Live Tour
# 12  7:30 PM CST                           Celebrate Christmas Tour
# 13  8:00 PM CST                                      with Wage War
# 14  7:30 PM CST                                    <No Opening Act

# %%
# Out:
#                                           artist                 day  \
# 0                                   Tauren Wells  November 15, 2022
# 1                                    Sometimes Y  November 17, 2022
# 2               Trombone Shorty & Orleans Avenue  November 18, 2022
# 3                               Dropkick Murphys  November 19, 2022
# 4   JOHNNYSWIM, Bryan Sutton & Dr. Curt Thompson  November 20, 2022
# 5                 Opry NextStage Live In Concert  November 20, 2022
# 6                               Christmas 4 Kids  November 21, 2022
# 7                                    Omar Apollo  November 22, 2022
# 8                                       W.A.S.P.  November 23, 2022
# 9                                 Brett Eldredge  November 25, 2022
# 10                                Brett Eldredge  November 26, 2022
# 11                                Brett Eldredge  November 27, 2022
# 12                   Natalie Grant & Danny Gokey  November 28, 2022
# 13                             A Day To Remember  November 29, 2022
# 14                                The Piano Guys  November 30, 2022
# 15           Jason Bonham’s Led Zeppelin Evening  November 30, 2022
# 16                                 The Mavericks   December 1, 2022
# 17                                 The Mavericks   December 2, 2022
# 18                                     The Smile   December 3, 2022
# 19                               Andrew Peterson   December 4, 2022
# 20                               Andrew Peterson   December 5, 2022
# 21                                 Lauren Daigle   December 6, 2022
# 22                                 Lauren Daigle   December 7, 2022
# 23                                 Lauren Daigle   December 8, 2022
# 24                         Allman Family Revival   December 9, 2022
# 25                                   LeAnn Rimes  December 10, 2022
# 26                        Amy Grant & Vince Gill  December 12, 2022
# 27                        Amy Grant & Vince Gill  December 13, 2022
# 28                        Amy Grant & Vince Gill  December 14, 2022
# 29                                    Louis C.K.  December 14, 2022
# 30                        Amy Grant & Vince Gill  December 15, 2022
# 31                               Smokey Robinson  December 16, 2022
# 32                        Amy Grant & Vince Gill  December 17, 2022
# 33                        Amy Grant & Vince Gill  December 17, 2022
# 34                        Amy Grant & Vince Gill  December 18, 2022
# 35                            for King + Country  December 18, 2022
# 36                        Amy Grant & Vince Gill  December 18, 2022
# 37                            for King + Country  December 19, 2022
# 38                                   Aaron Lewis  December 19, 2022
# 39                        Amy Grant & Vince Gill  December 20, 2022
# 40                        Amy Grant & Vince Gill  December 20, 2022
# 41                        Amy Grant & Vince Gill  December 21, 2022
# 42                        Amy Grant & Vince Gill  December 21, 2022
# 43       Music City Chorus Christmas Celebration  December 22, 2022
# 44                    Home Free Family Christmas  December 23, 2022
# 45         NUTCRACKER! Magic of Christmas Ballet  December 24, 2022
# 46         NUTCRACKER! Magic of Christmas Ballet  December 24, 2022
# 47                        Old Crow Medicine Show  December 30, 2022
# 48                        Old Crow Medicine Show  December 31, 2022
# 49   Celebrating the Life of Justin Townes Earle    January 4, 2023
#
#            time                                       opening_acts
# 0   7:30 PM CST  with special guests Aaron Cole and Lakewood Music
# 1   7:30 PM CST              Yelawolf & Shooter Jennings introduce
# 2   8:00 PM CST                              with Devon Gilfillian
# 3   7:30 PM CST                      This Machine ... Theater Tour
# 4   7:30 PM CST   Tokens Show presents No Small Endeavor featuring
# 5   7:30 PM CST                                    <No Opening Act
# 6   7:00 PM CST  with special guests Chris Young, Phil Vassar, ...
# 7   7:30 PM CST                                 The Prototype Tour
# 8   7:30 PM CST                           40 Years Live World Tour
# 9   8:00 PM CST                                     Glow Live Tour
# 10  8:00 PM CST                                     Glow Live Tour
# 11  8:00 PM CST                                     Glow Live Tour
# 12  7:30 PM CST                           Celebrate Christmas Tour
# 13  8:00 PM CST                                      with Wage War
# 14  7:30 PM CST                                    <No Opening Act
# 15  8:00 PM CST                                   <No Opening Act>
# 16  8:00 PM CST                    with special guest JD McPherson
# 17  8:00 PM CST                    with special guest JD McPherson
# 18  8:00 PM CST           Thom Yorke, Jonny Greenwood, Tom Skinner
# 19  7:00 PM CST                             Behold the Lamb of God
# 20  7:00 PM CST                             Behold the Lamb of God
# 21  7:30 PM CST                          The Behold Christmas Tour
# 22  7:30 PM CST                          The Behold Christmas Tour
# 23  7:30 PM CST                          The Behold Christmas Tour
# 24  8:00 PM CST                                     The 6th Annual
# 25  8:00 PM CST                              Joy: The Holiday Show
# 26  7:30 PM CST                             Christmas at the Ryman
# 27  7:30 PM CST                             Christmas at the Ryman
# 28  7:30 PM CST                             Christmas at the Ryman
# 29  7:30 PM CST                                    <No Opening Act
# 30  7:30 PM CST                             Christmas at the Ryman
# 31  8:00 PM CST                                   Music & Memories
# 32  3:00 PM CST                             Christmas at the Ryman
# 33  7:30 PM CST                             Christmas at the Ryman
# 34  3:00 PM CST                             Christmas at the Ryman
# 35  7:00 PM CST                                    <No Opening Act
# 36  7:30 PM CST                             Christmas at the Ryman
# 37  7:00 PM CST                                    2nd Show Added!
# 38  7:30 PM CST                                   <No Opening Act>
# 39  3:00 PM CST                             Christmas at the Ryman
# 40  7:30 PM CST                             Christmas at the Ryman
# 41  3:00 PM CST                             Christmas at the Ryman
# 42  7:30 PM CST                             Christmas at the Ryman
# 43  7:00 PM CST                                  with David Phelps
# 44  8:00 PM CST  with Texas Hill, Abby Anderson, Brooke Eden, C...
# 45  1:00 PM CST                                   <No Opening Act>
# 46  5:00 PM CST                                   <No Opening Act>
# 47  8:00 PM CST                 with Molly Tuttle & Golden Highway
# 48  9:00 PM CST                 with Molly Tuttle & Golden Highway
# 49  7:30 PM CST           with Steve Earle & The Dukes and Friends
